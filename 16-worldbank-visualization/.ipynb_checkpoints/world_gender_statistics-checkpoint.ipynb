# %% [markdown]
# # Relation between Country development and its energy usage
#
# Data used in this visualization provided by worldbank.
#
# ### Dataset
#     Dataset is collection of gender statistics, compiled from various international source.https://databank.worldbank.org/source/gender-statistics.
#
#     Choosed timeline of data between last 10 years 2011-2021

# %%
# Importing python packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loding data set
raw_df = pd.read_csv("data/data.csv")

# %%
raw_df.shape
# Out:
# (5570, 14)

# %%
raw_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2020 [YR2020]', '2019 [YR2019]', '2018 [YR2018]', '2017 [YR2017]',
#        '2016 [YR2016]', '2015 [YR2015]', '2014 [YR2014]', '2013 [YR2013]',
#        '2012 [YR2012]', '2011 [YR2011]'],
#       dtype='object')

# %%
raw_df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                          Series Name           Series Code  \
# 0  Contraceptive prevalence, any methods (% of wo...        SP.DYN.CONU.ZS
# 1  Maternal mortality ratio (modeled estimate, pe...           SH.STA.MMRT
# 2  Adolescent fertility rate (births per 1,000 wo...           SP.ADO.TFRT
# 3            Life expectancy at birth, total (years)        SP.DYN.LE00.IN
# 4  Female share of graduates in Engineering, Manu...  SE.TER.GRAD.FE.EN.ZS
#
#    2020 [YR2020]  2019 [YR2019]  2018 [YR2018]  2017 [YR2017]  2016 [YR2016]  \
# 0            NaN            NaN            NaN      39.685068            NaN
# 1            NaN            NaN            NaN     398.000000     408.000000
# ...

# %%
# Melting the individual years columns to be one column with the individual years as rows
id_vars = ['Country Name', 'Country Code', 'Series Name', 'Series Code']

# %%
dfmelt = pd.melt(frame=raw_df,id_vars=id_vars, var_name="year", value_name="value")

# %%
# Formatting 
dfmelt["year"] = dfmelt["year"].str.extract('(\d+)', expand=False).astype(int)
dfmelt["value"] = dfmelt["value"].astype(float)

# %%
# Cleaning out unnecessary rows with empty values
dfmelt = dfmelt.dropna()

# %%
dfmelt = dfmelt[["Country Name",
         "Country Code",
         "Series Name",
         "Series Code",
         "year",
         "value"]]

dfmelt = dfmelt.sort_values(ascending=True, by=["Country Name","Series Name","year"])

# %%
dfmelt.tail()
# Out:
#       Country Name Country Code  \
# 44535     Zimbabwe          ZWE
# 38965     Zimbabwe          ZWE
# 33395     Zimbabwe          ZWE
# 27825     Zimbabwe          ZWE
# 22255     Zimbabwe          ZWE
#
#                                              Series Name  Series Code  year  \
# 44535  Maternal mortality ratio (modeled estimate, pe...  SH.STA.MMRT  2013
# 38965  Maternal mortality ratio (modeled estimate, pe...  SH.STA.MMRT  2014
# 33395  Maternal mortality ratio (modeled estimate, pe...  SH.STA.MMRT  2015
# 27825  Maternal mortality ratio (modeled estimate, pe...  SH.STA.MMRT  2016
# 22255  Maternal mortality ratio (modeled estimate, pe...  SH.STA.MMRT  2017
#
#        value
# 44535  509.0
# 38965  494.0
# 33395  480.0
# 27825  468.0
# 22255  458.0

# %%
dfmelt.head()
# Out:
#       Country Name Country Code  \
# 51140  Afghanistan          AFG
# 45570  Afghanistan          AFG
# 40000  Afghanistan          AFG
# 34430  Afghanistan          AFG
# 28860  Afghanistan          AFG
#
#                                              Series Name  Series Code  year  \
# 51140  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT  2011
# 45570  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT  2012
# 40000  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT  2013
# 34430  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT  2014
# 28860  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT  2015
#
#          value
# 51140  107.256
# 45570  100.797
# 40000   94.429
# 34430   88.061
# 28860   81.693

# %%
#Un stacking column
df = pd.pivot_table(dfmelt, index=["Country Name","year"], columns="Series Name", values="value")

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.head()
# Out:
# Series Name Country Name  year  \
# 0            Afghanistan  2011
# 1            Afghanistan  2012
# 2            Afghanistan  2013
# 3            Afghanistan  2014
# 4            Afghanistan  2015
#
# Series Name  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                      107.256
# 1                                                      100.797
# 2                                                       94.429
# 3                                                       88.061
# 4                                                       81.693
#
# Series Name  Contraceptive prevalence, any methods (% of women ages 15-49)  \
# 0                                                         21.2
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# ...

# %%
sns.set(rc={"figure.figsize":(8, 6)}) #width=3, #height=4

# %% [markdown]
# ### Contraceptive use (ANY method) vs Maternal Mortality rate

# %%
sns.scatterplot(data=df, x= 'Contraceptive prevalence, any methods (% of women ages 15-49)',
                        y ='Maternal mortality ratio (modeled estimate, per 100,000 live births)')

Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)
# Out:
# <AxesSubplot:xlabel='Contraceptive prevalence, any methods (% of women ages 15-49)', ylabel='Maternal mortality ratio (modeled estimate, per 100,000 live births)'>

# %% [markdown]
# ##### There appears to be a negative correlation between contraceptive use and maternal mortality.

# %%
sns.regplot(data=df, x= "Contraceptive prevalence, any methods (% of women ages 15-49)",
            y="Adolescent fertility rate (births per 1,000 women ages 15-19)")
# Out:
# <AxesSubplot:xlabel='Contraceptive prevalence, any methods (% of women ages 15-49)', ylabel='Adolescent fertility rate (births per 1,000 women ages 15-19)'>

# %% [markdown]
# ##### A clear Negative correlation was found between Contraceptive use and Adolescent fertility rate

# %%
sns.regplot(data=df, 
            x="Contraceptive prevalence, any methods (% of women ages 15-49)", y="Life expectancy at birth, total (years)")
# Out:
# <AxesSubplot:xlabel='Contraceptive prevalence, any methods (% of women ages 15-49)', ylabel='Life expectancy at birth, total (years)'>

# %% [markdown]
# ##### There is a clear positive correlation between Use of Contraception and Life Expectancy

# %%
df.columns
# Out:
# Index(['Country Name', 'year',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Contraceptive prevalence, any methods (% of women ages 15-49)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)',
#        'Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)',
#        'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)',
#        'Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)',
#        'Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative)',
# ...

# %% [markdown]
# ##### Female share of employment in senior and middle management (%)

# %%
sns.displot(df['Female share of employment in senior and middle management (%)'].dropna(), bins=25)

# %% [markdown]
# ##### Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)

# %%
sns.displot(df['Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)'].dropna(), bins=25)

# %% [markdown]
# ##### Female share of graduates in Engineering, Manufacturing and Construction programmes, tertiary (%)

# %%
sns.displot(df['Female share of graduates in Engineering, Manufacturing and Construction programmes, tertiary (%)'].dropna(), bins=25)

# %% [markdown]
# ##### Educational attainment, at least Bachelor's or equivalent, population 25+, female (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)">

# %% [markdown]
# ##### Educational attainment, at least Bachelor's or equivalent, population 25+, male (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)">

# %% [markdown]
# ##### Educational attainment, at least completed lower secondary, population 25+, male (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)'>

# %% [markdown]
# ##### Educational attainment, at least completed post-secondary, population 25+, female (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)'>

# %% [markdown]
# ##### Educational attainment, at least completed primary, population 25+ years, female (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)'>

# %% [markdown]
# ##### Educational attainment, at least completed primary, population 25+ years, male (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)'>

# %% [markdown]
# ##### Educational attainment, at least completed short-cycle tertiary, population 25+, female (%)

# %%
sns.barplot(data=df, x="year",
                        y ="Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)'>

# %%
sns.regplot(data=df, x= 'Contraceptive prevalence, any methods (% of women ages 15-49)',
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='Contraceptive prevalence, any methods (% of women ages 15-49)', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)">

# %% [markdown]
# ##### much stronger correlation was found between Female Educational attainment 25+ and Contraceptive use.

# %%
sns.regplot(data=df, x= 'Contraceptive prevalence, any methods (% of women ages 15-49)',
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='Contraceptive prevalence, any methods (% of women ages 15-49)', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)">

# %% [markdown]
# ##### much stronger correlation was found between male Educational attainment 25+ and Contraceptive use.

# %%
sns.regplot(data=df, x= 'Life expectancy at birth, total (years)',
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth, total (years)', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)">

# %% [markdown]
# ##### There's also a slight correlation between Female Bachelor degree achievement and Life Expectancy

# %%
sns.regplot(data=df, x= 'GDP per capita (Current US$)',
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel='GDP per capita (Current US$)', ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)">

# %% [markdown]
# ##### GDP also positive correlated with female eucation

# %%
sns.regplot(data=df, x= "Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)",
                        y ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel="Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)", ylabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)">

# %%
sns.regplot(data=df, y= "Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)",
                        x ="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")
# Out:
# <AxesSubplot:xlabel="Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)", ylabel='Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)'>

# %% [markdown]
# ### Conculsion
#
# The most positive  correlation found was between the decision maker of a woman's health choices and the use of any method of Contraception.
#
#
# Another Strong correlation was found  between Contraceptive Use (Any method) and Life Expectancy.
#
# There is strong corelation between Education and use of contraception. This helps us to find effective way to reduce poverty and over population issue which is education.
#
# A clear negative correlation was found between Contraceptive use and Adolescent fertility rate. This may be caused by affluence or culture
